# %% [markdown]
# ### Przykładowy program w Jupyter

# %%
#importowanie bibliotek
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('D:/DYDAKTYKA/Python/dane/Si.txt', skiprows=2) 
print(data[0:5,:])
# Out:
# [[4.96     1.683594 3.708435]
#  [4.769231 1.802324 4.167128]
#  [4.592593 2.179194 4.77542 ]
#  [4.428571 3.108246 5.403376]
#  [4.275862 4.542185 5.154986]]

# %%
energy = data[:,0]
print(f'Energia fotonu {energy[:5]}')
n = data[:,1]
print(f'n {energy[:5]}')
k = data[:,2]
print(f'k: {energy[:5]}')
# Out:
# Energia fotonu [4.96     4.769231 4.592593 4.428571 4.275862]
# n [4.96     4.769231 4.592593 4.428571 4.275862]
# k: [4.96     4.769231 4.592593 4.428571 4.275862]

# %% [markdown]
# #### Wizualizacja danych

# %%
plt.plot(energy, n)
plt.plot(energy, k)
plt.xlabel('Energia fotonu, eV')
plt.ylabel('n, k')
plt.show()

# %% [markdown]
# #### Przeliczenie z eV --> nm
# ## $nm = \frac{1026}{eV}$

# %%
wvl = 1026/energy
print(wvl[:5])
# Out:
# [206.85483871 215.12902185 223.40320599 231.67744178 239.95161677]

# %%
plt.plot(wvl, n)
plt.plot(wvl, k)
plt.xlabel('wavelength, nm')
plt.ylabel('n, k')
plt.show()

# %% [markdown]
# ## Zadanie dla Studentów
#
# Oblicz i wykreśl współczynnik absorpcji

# %% [markdown]
# ### Wzór:
# ### $\alpha = \frac{4*\pi*k}{\lambda}$
